# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import nltk
from gensim import corpora, models, similarities
from gensim.models import Word2Vec
from gensim.test.utils import common_texts

# %% [markdown]
# # **load data**

# %%
with open ("/kaggle/input/word2vec/data", "r") as myfile:
    data = myfile.read().splitlines()

# %%
data
# Out:
# ['**Morocco and Marrakech: A Tapestry of Tradition and Modernity** Morocco, located at the crossroads of Europe and Africa, is a country drenched in history, mystery, and cultural richness. A testament to the ancient civilizations that once flourished here, this North African kingdom boasts a unique blend of Arab, Berber, and European influences. At the heart of Morocco\'s rich tapestry lies Marrakech, one of its four imperial cities and a vibrant epicenter of tradition and modernity. **Geographical Significance** Morocco is bordered by the Atlantic Ocean to the west, the Mediterranean Sea to the north, Algeria to the east and southeast, and the vast Sahara desert to the south. Its strategic location has historically made it a sought-after territory and a melting pot of cultures, religions, and trade routes. **Marrakech: The Red City** Marrakech, often referred to as "The Red City" due to its distinctive red-hued buildings, stands against the backdrop of the snow-capped Atlas Mountains. Established in the 11th century, it has remained a crucial political, economic, and cultural center of Morocco. **Journey through the Medina** Marrakech\'s old town, the Medina, is a UNESCO World Heritage site and a labyrinthine maze of narrow alleys, bustling souks, and historical landmarks. The Djemaa el-Fna Square lies at the heart of the Medina and comes alive every evening with storytellers, musicians, snake charmers, and food stalls offering tantalizing Moroccan delicacies. **Palaces and Gardens** The city is also home to grand palaces like the Bahia Palace, showcasing intricate Islamic architecture, and the Saadian Tombs, remnants of the Saadian dynasty. The Majorelle Garden, restored by the fashion designer Yves Saint Laurent, is a tranquil oasis of cacti, palm trees, and cobalt blue accents. **Modern Marrakech** While tradition and history permeate Marrakech, the city is not averse to the modern world. Gueliz, the new town, is brimming with contemporary art galleries, stylish cafes, and chic boutiques, offering a stark contrast to the ancient Medina. **Moroccan Cuisine** No journey through Morocco and Marrakech would be complete without indulging in the local cuisine. Tagines, couscous, and pastilla are just a few of the many dishes that combine a plethora of flavors and spices like saffron, cumin, and mint. Paired with Moroccan mint tea, the culinary experience is truly unparalleled. **In Conclusion** Morocco, with Marrakech at its heart, offers travelers an unparalleled journey through time. The convergence of history, culture, architecture, and gastronomy makes it an enthralling destination for those seeking both adventure and reflection. As the Moroccan proverb goes, "He who does not travel does not know the value of men." In the case of Morocco and Marrakech, it\'s not just the value of men, but also the value of time, tradition, and tales that have spanned centuries.']

# %% [markdown]
# # **clean data**

# %%
mod_data = []
for w in data:
    mod_string = w.replace("**","")
    mod_data.append(mod_string)

# %% [markdown]
# **function to remove punctuation**

# %%
import string
def remove_punctuation(text):
    translator = str.maketrans('','',string.punctuation)
    text_without_punctuation = text.translate(translator)
    return text_without_punctuation

# %% [markdown]
# **function to remove stopwords**

# %%
from nltk.corpus import stopwords
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stopwords.words('english')])

# %% [markdown]
# **function for lemmitization**

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
def lemmatizing(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc])

# %%
text_no_punc = []
for w in mod_data:
    text_no_punc.append(remove_punctuation(mod_string))

# %%
text_no_punc
# Out:
# ['Morocco and Marrakech A Tapestry of Tradition and Modernity Morocco located at the crossroads of Europe and Africa is a country drenched in history mystery and cultural richness A testament to the ancient civilizations that once flourished here this North African kingdom boasts a unique blend of Arab Berber and European influences At the heart of Moroccos rich tapestry lies Marrakech one of its four imperial cities and a vibrant epicenter of tradition and modernity Geographical Significance Morocco is bordered by the Atlantic Ocean to the west the Mediterranean Sea to the north Algeria to the east and southeast and the vast Sahara desert to the south Its strategic location has historically made it a soughtafter territory and a melting pot of cultures religions and trade routes Marrakech The Red City Marrakech often referred to as The Red City due to its distinctive redhued buildings stands against the backdrop of the snowcapped Atlas Mountains Established in the 11th century it has remained a crucial political economic and cultural center of Morocco Journey through the Medina Marrakechs old town the Medina is a UNESCO World Heritage site and a labyrinthine maze of narrow alleys bustling souks and historical landmarks The Djemaa elFna Square lies at the heart of the Medina and comes alive every evening with storytellers musicians snake charmers and food stalls offering tantalizing Moroccan delicacies Palaces and Gardens The city is also home to grand palaces like the Bahia Palace showcasing intricate Islamic architecture and the Saadian Tombs remnants of the Saadian dynasty The Majorelle Garden restored by the fashion designer Yves Saint Laurent is a tranquil oasis of cacti palm trees and cobalt blue accents Modern Marrakech While tradition and history permeate Marrakech the city is not averse to the modern world Gueliz the new town is brimming with contemporary art galleries stylish cafes and chic boutiques offering a stark contrast to the ancient Medina Moroccan Cuisine No journey through Morocco and Marrakech would be complete without indulging in the local cuisine Tagines couscous and pastilla are just a few of the many dishes that combine a plethora of flavors and spices like saffron cumin and mint Paired with Moroccan mint tea the culinary experience is truly unparalleled In Conclusion Morocco with Marrakech at its heart offers travelers an unparalleled journey through time The convergence of history culture architecture and gastronomy makes it an enthralling destination for those seeking both adventure and reflection As the Moroccan proverb goes He who does not travel does not know the value of men In the case of Morocco and Marrakech its not just the value of men but also the value of time tradition and tales that have spanned centuries']

# %%
text_no_sw = []
for w in text_no_punc:
    text_no_sw.append(remove_stopwords(w))

# %%
text_no_sw
# Out:
# ['Morocco Marrakech A Tapestry Tradition Modernity Morocco located crossroads Europe Africa country drenched history mystery cultural richness A testament ancient civilizations flourished North African kingdom boasts unique blend Arab Berber European influences At heart Moroccos rich tapestry lies Marrakech one four imperial cities vibrant epicenter tradition modernity Geographical Significance Morocco bordered Atlantic Ocean west Mediterranean Sea north Algeria east southeast vast Sahara desert south Its strategic location historically made soughtafter territory melting pot cultures religions trade routes Marrakech The Red City Marrakech often referred The Red City due distinctive redhued buildings stands backdrop snowcapped Atlas Mountains Established 11th century remained crucial political economic cultural center Morocco Journey Medina Marrakechs old town Medina UNESCO World Heritage site labyrinthine maze narrow alleys bustling souks historical landmarks The Djemaa elFna Square lies heart Medina comes alive every evening storytellers musicians snake charmers food stalls offering tantalizing Moroccan delicacies Palaces Gardens The city also home grand palaces like Bahia Palace showcasing intricate Islamic architecture Saadian Tombs remnants Saadian dynasty The Majorelle Garden restored fashion designer Yves Saint Laurent tranquil oasis cacti palm trees cobalt blue accents Modern Marrakech While tradition history permeate Marrakech city averse modern world Gueliz new town brimming contemporary art galleries stylish cafes chic boutiques offering stark contrast ancient Medina Moroccan Cuisine No journey Morocco Marrakech would complete without indulging local cuisine Tagines couscous pastilla many dishes combine plethora flavors spices like saffron cumin mint Paired Moroccan mint tea culinary experience truly unparalleled In Conclusion Morocco Marrakech heart offers travelers unparalleled journey time The convergence history culture architecture gastronomy makes enthralling destination seeking adventure reflection As Moroccan proverb goes He travel know value men In case Morocco Marrakech value men also value time tradition tales spanned centuries']

# %%
text_lemmatized = []
for w in text_no_sw:
    text_lemmatized.append(lemmatizing(w))

# %%
text_lemmatized
# Out:
# ['Morocco Marrakech A Tapestry Tradition Modernity Morocco locate crossroad Europe Africa country drench history mystery cultural richness a testament ancient civilization flourish north african kingdom boast unique blend arab Berber european influence at heart Moroccos rich tapestry lie Marrakech one four imperial city vibrant epicenter tradition modernity geographical Significance Morocco border Atlantic Ocean west Mediterranean Sea north Algeria east southeast vast Sahara desert south its strategic location historically make soughtafter territory melting pot culture religion trade route Marrakech the Red City Marrakech often refer the Red City due distinctive redhue building stand backdrop snowcappe Atlas Mountains establish 11th century remain crucial political economic cultural center Morocco Journey Medina Marrakechs old town Medina UNESCO World Heritage site labyrinthine maze narrow alley bustle souks historical landmark the Djemaa elfna Square lie heart Medina come alive every evening storyteller musician snake charmer food stall offer tantalize Moroccan delicacy Palaces Gardens the city also home grand palace like Bahia Palace showcase intricate islamic architecture saadian Tombs remnant saadian dynasty the Majorelle Garden restore fashion designer Yves Saint Laurent tranquil oasis cacti palm tree cobalt blue accent Modern Marrakech while tradition history permeate Marrakech city averse modern world Gueliz new town brim contemporary art gallery stylish cafe chic boutique offer stark contrast ancient Medina Moroccan Cuisine no journey Morocco Marrakech would complete without indulge local cuisine tagine couscous pastilla many dish combine plethora flavors spice like saffron cumin mint pair moroccan mint tea culinary experience truly unparalleled in Conclusion Morocco Marrakech heart offer traveler unparalleled journey time the convergence history culture architecture gastronomy make enthral destination seek adventure reflection as moroccan proverb go he travel know value man in case Morocco Marrakech value man also value time tradition tale span century']

# %% [markdown]
# # **Tokenization**

# %%
tokenized_corpus = [nltk.word_tokenize(w)for w in text_lemmatized]

# %% [markdown]
# # **initializing the model**

# %%
w2v_model = models.Word2Vec(tokenized_corpus, vector_size=100, window=5, min_count=1, sg=1)

# %% [markdown]
# # **saving the model**

# %%
w2v_model.save('w2v_model')

# %% [markdown]
# # **Loading the model**

# %%
model = Word2Vec.load('/kaggle/working/w2v_model')

# %% [markdown]
# # **Vectorial Representation**

# %%
word_vecs = []
for word in tokenized_corpus[0]:
    if word in model.wv.index_to_key:
        vector = model.wv[word]
        word_vecs.append((word, vector))
    else:
        word_vectors.append((word, None))

# %% [markdown]
# # **Similarities**

# %%
from sklearn.metrics.pairwise import cosine_similarity
import itertools

# %%
similarity_scores = {}
for w1, w2 in itertools.combinations(word_vecs, 2):
    word1 = w1[0]
    vector1 = w1[1]
    word2 = w2[0]
    vector2 = w2[1]
    similarity = cosine_similarity([vector1],[vector2])[0][0]
    similarity_scores[(word1, word2)] = similarity

# %%
similarity_scores
# Out:
# {('Morocco', 'Marrakech'): 0.0040270034,
#  ('Morocco', 'A'): 0.06316205,
#  ('Morocco', 'Tapestry'): 0.039247967,
#  ('Morocco', 'Tradition'): -0.07628815,
#  ('Morocco', 'Modernity'): 0.024023332,
#  ('Morocco', 'Morocco'): 1.0000002,
#  ('Morocco', 'locate'): 0.044367556,
#  ('Morocco', 'crossroad'): -0.21409439,
#  ('Morocco', 'Europe'): 0.00017673173,
#  ('Morocco', 'Africa'): 0.045989435,
#  ('Morocco', 'country'): 0.04639391,
#  ('Morocco', 'drench'): -0.21707858,
#  ('Morocco', 'history'): -0.099658094,
#  ('Morocco', 'mystery'): 0.06707465,
#  ('Morocco', 'cultural'): -0.014020264,
#  ('Morocco', 'richness'): 0.030593462,
#  ('Morocco', 'a'): -0.2237588,
#  ('Morocco', 'testament'): -0.00065753167,
#  ('Morocco', 'ancient'): 0.19023006,
#  ('Morocco', 'civilization'): -0.0016548485,
#  ('Morocco', 'flourish'): -0.053755783,
#  ('Morocco', 'north'): 0.16563228,
#  ('Morocco', 'african'): 0.101218745,
#  ('Morocco', 'kingdom'): 0.026761828,
#  ('Morocco', 'boast'): -0.044352293,
#  ('Morocco', 'unique'): 0.16011287,
#  ('Morocco', 'blend'): -0.06798921,
#  ('Morocco', 'arab'): -0.05616196,
#  ('Morocco', 'Berber'): -0.08737483,
#  ('Morocco', 'european'): -0.103113875,
#  ('Morocco', 'influence'): 0.18748567,
#  ('Morocco', 'at'): 0.0011512634,
#  ('Morocco', 'heart'): 0.04075593,
#  ('Morocco', 'Moroccos'): 0.03789214,
#  ('Morocco', 'rich'): 0.024230456,
#  ('Morocco', 'tapestry'): 0.09188868,
#  ('Morocco', 'lie'): -0.09475705,
#  ('Morocco', 'one'): 0.08599716,
#  ('Morocco', 'four'): -0.016133297,
#  ('Morocco', 'imperial'): -0.030206311,
#  ('Morocco', 'city'): 0.00542609,
#  ('Morocco', 'vibrant'): -0.07736955,
#  ('Morocco', 'epicenter'): -0.053991713,
#  ('Morocco', 'tradition'): -0.10439188,
#  ('Morocco', 'modernity'): -0.08557215,
#  ('Morocco', 'geographical'): 0.070951305,
#  ('Morocco', 'Significance'): -0.05407692,
#  ('Morocco', 'border'): 0.0014128496,
#  ('Morocco', 'Atlantic'): -0.025240615,
#  ('Morocco', 'Ocean'): -0.18112001,
#  ('Morocco', 'west'): 0.0118384175,
#  ('Morocco', 'Mediterranean'): 0.0063402113,
#  ('Morocco', 'Sea'): -0.03333246,
#  ('Morocco', 'Algeria'): 0.15794162,
#  ('Morocco', 'east'): 0.09721323,
#  ('Morocco', 'southeast'): 0.18521264,
#  ('Morocco', 'vast'): 0.059547037,
#  ('Morocco', 'Sahara'): -0.07373847,
#  ('Morocco', 'desert'): -0.10115228,
#  ('Morocco', 'south'): 0.107770406,
#  ('Morocco', 'its'): -0.06642813,
#  ('Morocco', 'strategic'): 0.0865178,
#  ('Morocco', 'location'): 0.033517,
#  ('Morocco', 'historically'): -0.06697964,
#  ('Morocco', 'make'): 0.18868911,
#  ('Morocco', 'soughtafter'): 0.08789098,
#  ('Morocco', 'territory'): -0.079758294,
#  ('Morocco', 'melting'): -0.2054846,
#  ('Morocco', 'pot'): -0.05670536,
#  ('Morocco', 'culture'): -0.064222366,
#  ('Morocco', 'religion'): 0.030515056,
#  ('Morocco', 'trade'): 0.045023866,
#  ('Morocco', 'route'): 0.11630561,
#  ('Morocco', 'the'): -0.011297936,
#  ('Morocco', 'Red'): 0.13958025,
#  ('Morocco', 'City'): -0.07558323,
#  ('Morocco', 'often'): 0.011189218,
#  ('Morocco', 'refer'): -0.15203539,
#  ('Morocco', 'due'): -0.20465046,
#  ('Morocco', 'distinctive'): 0.047602795,
#  ('Morocco', 'redhue'): -0.16124214,
#  ('Morocco', 'building'): 0.053923648,
#  ('Morocco', 'stand'): 0.07973514,
#  ('Morocco', 'backdrop'): 0.16081966,
#  ('Morocco', 'snowcappe'): -0.13953017,
#  ('Morocco', 'Atlas'): -0.034915984,
#  ('Morocco', 'Mountains'): 0.13934103,
#  ('Morocco', 'establish'): -0.02300192,
#  ('Morocco', '11th'): -0.0058165607,
#  ('Morocco', 'century'): 0.12652932,
#  ('Morocco', 'remain'): -0.09394137,
#  ('Morocco', 'crucial'): -0.05055575,
#  ('Morocco', 'political'): -0.047187243,
#  ('Morocco', 'economic'): -0.05066581,
#  ('Morocco', 'center'): -0.16264316,
#  ('Morocco', 'Journey'): -0.004269731,
#  ('Morocco', 'Medina'): 0.06812801,
#  ('Morocco', 'Marrakechs'): 0.05256033,
#  ('Morocco', 'old'): -0.010185545,
#  ('Morocco', 'town'): -0.002461099,
#  ('Morocco', 'UNESCO'): 0.08358325,
#  ('Morocco', 'World'): -0.010751171,
#  ('Morocco', 'Heritage'): 0.18308485,
#  ('Morocco', 'site'): -0.07928709,
#  ('Morocco', 'labyrinthine'): -0.032464266,
#  ('Morocco', 'maze'): 0.021984182,
#  ('Morocco', 'narrow'): 0.10887138,
#  ('Morocco', 'alley'): 0.018444559,
#  ('Morocco', 'bustle'): 0.038344346,
#  ('Morocco', 'souks'): 0.08208354,
#  ('Morocco', 'historical'): 0.0013976111,
#  ('Morocco', 'landmark'): -0.01690388,
#  ('Morocco', 'Djemaa'): -0.06609856,
#  ('Morocco', 'elfna'): 0.12304442,
#  ('Morocco', 'Square'): -0.028529096,
#  ('Morocco', 'come'): -0.0072134137,
#  ('Morocco', 'alive'): -0.009878727,
#  ('Morocco', 'every'): -0.028157363,
#  ('Morocco', 'evening'): -0.09660446,
#  ('Morocco', 'storyteller'): 0.05145733,
#  ('Morocco', 'musician'): -0.24849682,
#  ('Morocco', 'snake'): -0.08990478,
#  ('Morocco', 'charmer'): -0.12616222,
#  ('Morocco', 'food'): -0.057404682,
#  ('Morocco', 'stall'): -0.020271935,
#  ('Morocco', 'offer'): 0.020706289,
#  ('Morocco', 'tantalize'): -0.047557026,
#  ('Morocco', 'Moroccan'): 0.1582382,
#  ('Morocco', 'delicacy'): 0.069251075,
#  ('Morocco', 'Palaces'): -0.17960273,
#  ('Morocco', 'Gardens'): 0.12693891,
#  ('Morocco', 'also'): 0.019203039,
#  ('Morocco', 'home'): -0.021609895,
#  ('Morocco', 'grand'): -0.12117744,
#  ('Morocco', 'palace'): 0.1544203,
#  ('Morocco', 'like'): 0.030266859,
#  ('Morocco', 'Bahia'): 0.029266682,
#  ('Morocco', 'Palace'): -0.0762728,
#  ('Morocco', 'showcase'): 0.17299828,
#  ('Morocco', 'intricate'): -0.16514705,
#  ('Morocco', 'islamic'): -0.06512754,
#  ('Morocco', 'architecture'): -0.12923305,
#  ('Morocco', 'saadian'): -0.0018055923,
#  ('Morocco', 'Tombs'): -0.1038185,
#  ('Morocco', 'remnant'): -0.003178358,
#  ('Morocco', 'dynasty'): 0.21513323,
#  ('Morocco', 'Majorelle'): -0.03494677,
#  ('Morocco', 'Garden'): -0.029635055,
#  ('Morocco', 'restore'): 0.024488444,
#  ('Morocco', 'fashion'): -0.19013104,
#  ('Morocco', 'designer'): -0.20626818,
#  ('Morocco', 'Yves'): -0.029726364,
#  ('Morocco', 'Saint'): -0.088989146,
#  ('Morocco', 'Laurent'): -0.11146799,
#  ('Morocco', 'tranquil'): 0.040476013,
#  ('Morocco', 'oasis'): -0.16084209,
#  ('Morocco', 'cacti'): 0.015351211,
#  ('Morocco', 'palm'): 0.04580471,
#  ('Morocco', 'tree'): 0.1792504,
#  ('Morocco', 'cobalt'): -0.011660296,
#  ('Morocco', 'blue'): 0.193402,
#  ('Morocco', 'accent'): 0.078602344,
#  ('Morocco', 'Modern'): -0.09747701,
#  ('Morocco', 'while'): -0.08512251,
#  ('Morocco', 'permeate'): 0.05845341,
#  ('Morocco', 'averse'): 0.093718104,
#  ('Morocco', 'modern'): 0.06379972,
#  ('Morocco', 'world'): -0.17431152,
#  ('Morocco', 'Gueliz'): 0.14632685,
#  ('Morocco', 'new'): 0.16857962,
#  ('Morocco', 'brim'): 0.22021201,
#  ('Morocco', 'contemporary'): -0.15533489,
#  ('Morocco', 'art'): -0.047665134,
#  ('Morocco', 'gallery'): 0.052875035,
#  ('Morocco', 'stylish'): -0.13970813,
#  ('Morocco', 'cafe'): -0.039718207,
#  ('Morocco', 'chic'): 0.10329193,
#  ('Morocco', 'boutique'): -0.025601124,
#  ('Morocco', 'stark'): -0.10307765,
#  ('Morocco', 'contrast'): -0.08111036,
#  ('Morocco', 'Cuisine'): 0.04131245,
#  ('Morocco', 'no'): 0.064925216,
#  ('Morocco', 'journey'): -0.011133255,
#  ('Morocco', 'would'): 0.11488259,
#  ('Morocco', 'complete'): -0.008747562,
#  ('Morocco', 'without'): 0.075340666,
#  ('Morocco', 'indulge'): 0.04016035,
#  ('Morocco', 'local'): -0.06092186,
#  ('Morocco', 'cuisine'): -0.055437375,
#  ('Morocco', 'tagine'): -0.02656097,
#  ('Morocco', 'couscous'): -0.058637053,
#  ('Morocco', 'pastilla'): -0.07022741,
#  ('Morocco', 'many'): 0.13776213,
#  ('Morocco', 'dish'): -0.11677788,
#  ('Morocco', 'combine'): 0.05879674,
#  ('Morocco', 'plethora'): 0.1806125,
#  ('Morocco', 'flavors'): -0.25441062,
#  ('Morocco', 'spice'): 0.019883841,
#  ('Morocco', 'saffron'): 0.022705633,
#  ('Morocco', 'cumin'): -0.047241133,
#  ('Morocco', 'mint'): 0.08795121,
#  ('Morocco', 'pair'): -0.06642849,
#  ('Morocco', 'moroccan'): -0.1578637,
#  ('Morocco', 'tea'): 0.10151949,
#  ('Morocco', 'culinary'): 0.058558535,
#  ('Morocco', 'experience'): 0.0058094617,
#  ('Morocco', 'truly'): 0.08008927,
#  ('Morocco', 'unparalleled'): 0.12602286,
#  ('Morocco', 'in'): -0.106280915,
#  ('Morocco', 'Conclusion'): -0.15637541,
#  ('Morocco', 'traveler'): 0.11794056,
#  ('Morocco', 'time'): 0.03673914,
#  ('Morocco', 'convergence'): 0.060635507,
#  ('Morocco', 'gastronomy'): 0.17812762,
#  ('Morocco', 'enthral'): -0.13982256,
#  ('Morocco', 'destination'): 0.007976641,
#  ('Morocco', 'seek'): -0.06913106,
#  ('Morocco', 'adventure'): -0.11220088,
#  ('Morocco', 'reflection'): 0.1366595,
#  ('Morocco', 'as'): -0.2803731,
#  ('Morocco', 'proverb'): -0.027315723,
#  ('Morocco', 'go'): 0.013619054,
#  ('Morocco', 'he'): 0.15463042,
#  ('Morocco', 'travel'): -0.13700366,
#  ('Morocco', 'know'): 0.0024878872,
#  ('Morocco', 'value'): -0.09166774,
#  ('Morocco', 'man'): 0.014145325,
#  ('Morocco', 'case'): 0.03392341,
#  ('Morocco', 'tale'): -0.07476926,
#  ('Morocco', 'span'): 0.10605086,
#  ('Marrakech', 'A'): -0.06448211,
#  ('Marrakech', 'Tapestry'): 0.14008935,
#  ('Marrakech', 'Tradition'): -0.026529504,
#  ('Marrakech', 'Modernity'): 0.08716684,
#  ('Marrakech', 'Morocco'): 0.0040270034,
#  ('Marrakech', 'locate'): 0.066231355,
#  ('Marrakech', 'crossroad'): 0.041186586,
#  ('Marrakech', 'Europe'): 0.028169492,
#  ('Marrakech', 'Africa'): -0.05898847,
#  ('Marrakech', 'country'): -0.018472131,
#  ('Marrakech', 'drench'): 0.057427056,
#  ('Marrakech', 'history'): 0.05465287,
#  ('Marrakech', 'mystery'): 0.06658939,
#  ('Marrakech', 'cultural'): 0.16629604,
#  ('Marrakech', 'richness'): 0.04696358,
#  ('Marrakech', 'a'): 0.09296369,
#  ('Marrakech', 'testament'): 0.06304298,
#  ('Marrakech', 'ancient'): -0.03487902,
#  ('Marrakech', 'civilization'): 0.051048543,
#  ('Marrakech', 'flourish'): -0.19931228,
#  ('Marrakech', 'north'): 0.017488986,
#  ('Marrakech', 'african'): -0.031329136,
#  ('Marrakech', 'kingdom'): 0.004690389,
#  ('Marrakech', 'boast'): 0.019361658,
#  ('Marrakech', 'unique'): -0.074873045,
#  ('Marrakech', 'blend'): 0.049160317,
#  ('Marrakech', 'arab'): -0.025391825,
#  ('Marrakech', 'Berber'): 0.31019312,
#  ('Marrakech', 'european'): -0.03414129,
#  ('Marrakech', 'influence'): 0.25316328,
#  ('Marrakech', 'at'): -0.10668276,
#  ('Marrakech', 'heart'): 0.057446912,
#  ('Marrakech', 'Moroccos'): 0.016152343,
#  ('Marrakech', 'rich'): 0.013025481,
#  ('Marrakech', 'tapestry'): 0.09204577,
#  ('Marrakech', 'lie'): 0.0528754,
#  ('Marrakech', 'Marrakech'): 1.0,
#  ('Marrakech', 'one'): -0.18250893,
#  ('Marrakech', 'four'): 0.022013992,
#  ('Marrakech', 'imperial'): 0.056325287,
#  ('Marrakech', 'city'): -0.012730859,
#  ('Marrakech', 'vibrant'): 0.060401324,
#  ('Marrakech', 'epicenter'): -0.08103106,
#  ('Marrakech', 'tradition'): 0.12758319,
#  ('Marrakech', 'modernity'): -0.03781526,
#  ('Marrakech', 'geographical'): -0.013814476,
#  ('Marrakech', 'Significance'): -0.081941746,
#  ('Marrakech', 'border'): -0.03347823,
#  ('Marrakech', 'Atlantic'): 0.06645241,
#  ('Marrakech', 'Ocean'): 0.08906091,
#  ('Marrakech', 'west'): 0.014313628,
#  ('Marrakech', 'Mediterranean'): 0.010146383,
#  ('Marrakech', 'Sea'): 0.11923728,
#  ('Marrakech', 'Algeria'): 0.046426002,
#  ('Marrakech', 'east'): -0.071349815,
#  ('Marrakech', 'southeast'): -0.047451887,
#  ('Marrakech', 'vast'): 0.040139448,
#  ('Marrakech', 'Sahara'): -0.09949861,
#  ('Marrakech', 'desert'): 0.10903246,
#  ('Marrakech', 'south'): 0.042162657,
#  ('Marrakech', 'its'): 0.028681777,
#  ('Marrakech', 'strategic'): -0.10592325,
#  ('Marrakech', 'location'): 0.054341324,
#  ('Marrakech', 'historically'): 0.018660098,
#  ('Marrakech', 'make'): 0.121515095,
#  ('Marrakech', 'soughtafter'): -0.104781345,
#  ('Marrakech', 'territory'): 0.022115786,
#  ('Marrakech', 'melting'): 0.016445981,
#  ('Marrakech', 'pot'): 0.10590181,
#  ('Marrakech', 'culture'): -0.07256137,
#  ('Marrakech', 'religion'): 0.052609805,
#  ('Marrakech', 'trade'): 0.12497954,
#  ('Marrakech', 'route'): -0.022210222,
#  ('Marrakech', 'the'): 0.0017745128,
#  ('Marrakech', 'Red'): -0.026256131,
#  ('Marrakech', 'City'): 0.06115629,
#  ('Marrakech', 'often'): -0.009571549,
#  ('Marrakech', 'refer'): 0.1575157,
#  ('Marrakech', 'due'): -0.076794796,
#  ('Marrakech', 'distinctive'): 0.17377011,
#  ('Marrakech', 'redhue'): 0.10163229,
#  ('Marrakech', 'building'): -0.064469814,
#  ('Marrakech', 'stand'): 0.041141234,
#  ('Marrakech', 'backdrop'): -0.15254617,
#  ('Marrakech', 'snowcappe'): 0.08432371,
#  ('Marrakech', 'Atlas'): 0.21867125,
#  ('Marrakech', 'Mountains'): 0.051086377,
#  ('Marrakech', 'establish'): -0.1284183,
#  ('Marrakech', '11th'): 0.068454415,
#  ('Marrakech', 'century'): 0.060513426,
#  ('Marrakech', 'remain'): 0.019699497,
#  ('Marrakech', 'crucial'): 0.0021350258,
#  ('Marrakech', 'political'): 0.15227805,
#  ('Marrakech', 'economic'): 0.15417002,
#  ('Marrakech', 'center'): -0.0615473,
#  ('Marrakech', 'Journey'): 0.0658194,
#  ('Marrakech', 'Medina'): -0.09385146,
#  ('Marrakech', 'Marrakechs'): -0.04178067,
#  ('Marrakech', 'old'): 0.1045403,
#  ('Marrakech', 'town'): 0.030013446,
#  ('Marrakech', 'UNESCO'): 0.19010893,
#  ('Marrakech', 'World'): 0.13361949,
#  ('Marrakech', 'Heritage'): -0.043010663,
#  ('Marrakech', 'site'): 0.13225082,
#  ('Marrakech', 'labyrinthine'): 0.04432272,
#  ('Marrakech', 'maze'): 0.065766454,
#  ('Marrakech', 'narrow'): 0.1399314,
#  ('Marrakech', 'alley'): -0.11947157,
#  ('Marrakech', 'bustle'): 0.06220914,
#  ('Marrakech', 'souks'): -0.1045471,
#  ('Marrakech', 'historical'): 0.016373388,
#  ('Marrakech', 'landmark'): 0.049902104,
#  ('Marrakech', 'Djemaa'): 0.10714689,
#  ('Marrakech', 'elfna'): 0.0021729465,
#  ('Marrakech', 'Square'): 0.11661029,
#  ('Marrakech', 'come'): 0.04724273,
#  ('Marrakech', 'alive'): -0.097687475,
#  ('Marrakech', 'every'): 0.044117138,
#  ('Marrakech', 'evening'): -0.05169488,
#  ('Marrakech', 'storyteller'): 0.029099695,
#  ('Marrakech', 'musician'): 0.13980965,
#  ('Marrakech', 'snake'): 0.08299797,
#  ('Marrakech', 'charmer'): 0.04869,
#  ('Marrakech', 'food'): 0.052386977,
#  ('Marrakech', 'stall'): 0.11536907,
#  ('Marrakech', 'offer'): -0.005025189,
#  ('Marrakech', 'tantalize'): -0.011629423,
#  ('Marrakech', 'Moroccan'): -0.021529507,
#  ('Marrakech', 'delicacy'): 0.18745902,
#  ('Marrakech', 'Palaces'): -0.11771746,
#  ('Marrakech', 'Gardens'): 0.22422735,
#  ('Marrakech', 'also'): 0.11011573,
#  ('Marrakech', 'home'): -0.0668603,
#  ('Marrakech', 'grand'): 0.020856207,
#  ('Marrakech', 'palace'): -0.020176385,
#  ('Marrakech', 'like'): 0.24309362,
#  ('Marrakech', 'Bahia'): -0.04876221,
#  ('Marrakech', 'Palace'): -0.06454872,
#  ('Marrakech', 'showcase'): 0.28552225,
#  ('Marrakech', 'intricate'): -0.05554014,
#  ('Marrakech', 'islamic'): -0.09087973,
#  ('Marrakech', 'architecture'): 0.08026711,
#  ('Marrakech', 'saadian'): 0.10273904,
#  ('Marrakech', 'Tombs'): 0.18285647,
#  ('Marrakech', 'remnant'): 0.04856177,
#  ('Marrakech', 'dynasty'): -0.052886195,
#  ('Marrakech', 'Majorelle'): -0.07475263,
#  ('Marrakech', 'Garden'): 0.052224804,
#  ('Marrakech', 'restore'): 0.07310449,
#  ('Marrakech', 'fashion'): -0.17078564,
#  ('Marrakech', 'designer'): -0.002830884,
#  ('Marrakech', 'Yves'): 0.107746094,
#  ('Marrakech', 'Saint'): 0.07600352,
#  ('Marrakech', 'Laurent'): 0.033796467,
#  ('Marrakech', 'tranquil'): 0.067131646,
#  ('Marrakech', 'oasis'): -0.0735788,
#  ('Marrakech', 'cacti'): 0.024459293,
#  ('Marrakech', 'palm'): 0.08212767,
#  ('Marrakech', 'tree'): 0.05551206,
#  ('Marrakech', 'cobalt'): 0.01908287,
#  ('Marrakech', 'blue'): 0.28654715,
#  ('Marrakech', 'accent'): -0.009464209,
#  ('Marrakech', 'Modern'): 0.13137828,
#  ('Marrakech', 'while'): 0.027391933,
#  ('Marrakech', 'permeate'): 0.078317314,
#  ('Marrakech', 'averse'): -0.15323724,
#  ('Marrakech', 'modern'): 0.071027346,
#  ('Marrakech', 'world'): 0.09424867,
#  ('Marrakech', 'Gueliz'): -0.10492229,
#  ('Marrakech', 'new'): 0.06408651,
#  ('Marrakech', 'brim'): -0.017336648,
#  ('Marrakech', 'contemporary'): 0.111215755,
#  ('Marrakech', 'art'): 0.07529209,
#  ('Marrakech', 'gallery'): 0.076075196,
#  ('Marrakech', 'stylish'): 0.06514649,
#  ('Marrakech', 'cafe'): 0.2300346,
#  ('Marrakech', 'chic'): 0.029863158,
#  ('Marrakech', 'boutique'): 0.17452037,
#  ('Marrakech', 'stark'): -0.021571683,
#  ('Marrakech', 'contrast'): 0.037776385,
#  ('Marrakech', 'Cuisine'): -0.04548723,
#  ('Marrakech', 'no'): 0.10003194,
#  ('Marrakech', 'journey'): 0.1160759,
#  ('Marrakech', 'would'): 0.08832317,
#  ('Marrakech', 'complete'): 0.015690695,
#  ('Marrakech', 'without'): 0.0989757,
#  ('Marrakech', 'indulge'): -0.045525253,
#  ('Marrakech', 'local'): 0.08000739,
#  ('Marrakech', 'cuisine'): 0.0046854224,
#  ('Marrakech', 'tagine'): 0.03619618,
#  ('Marrakech', 'couscous'): 0.010956304,
#  ('Marrakech', 'pastilla'): 0.09195463,
#  ('Marrakech', 'many'): 0.023470558,
#  ('Marrakech', 'dish'): -0.11455083,
#  ('Marrakech', 'combine'): 0.10481017,
#  ('Marrakech', 'plethora'): -0.018426076,
#  ('Marrakech', 'flavors'): 0.021539034,
#  ('Marrakech', 'spice'): 0.21635228,
#  ('Marrakech', 'saffron'): 0.19118977,
#  ('Marrakech', 'cumin'): 0.014056072,
#  ('Marrakech', 'mint'): -0.09383921,
#  ('Marrakech', 'pair'): -0.05001856,
#  ('Marrakech', 'moroccan'): 0.019667424,
#  ('Marrakech', 'tea'): 0.15300585,
#  ('Marrakech', 'culinary'): 0.035705846,
#  ('Marrakech', 'experience'): -0.13259907,
#  ('Marrakech', 'truly'): -0.0024583903,
#  ('Marrakech', 'unparalleled'): -0.12675017,
#  ('Marrakech', 'in'): 0.21198745,
#  ('Marrakech', 'Conclusion'): -0.10448547,
#  ('Marrakech', 'traveler'): 0.055532746,
#  ('Marrakech', 'time'): -0.1286624,
#  ('Marrakech', 'convergence'): -0.10471365,
#  ('Marrakech', 'gastronomy'): 0.12783773,
#  ('Marrakech', 'enthral'): 0.006237277,
#  ('Marrakech', 'destination'): -0.06770952,
#  ('Marrakech', 'seek'): 0.103862986,
#  ('Marrakech', 'adventure'): -0.016785992,
#  ('Marrakech', 'reflection'): 0.072755665,
#  ('Marrakech', 'as'): -0.11468776,
#  ('Marrakech', 'proverb'): 0.057435412,
#  ('Marrakech', 'go'): -0.11185012,
#  ('Marrakech', 'he'): 0.024269603,
#  ('Marrakech', 'travel'): -0.14046274,
#  ('Marrakech', 'know'): -0.07613202,
#  ('Marrakech', 'value'): 0.23118393,
#  ('Marrakech', 'man'): -0.10254621,
#  ('Marrakech', 'case'): -0.01855624,
#  ('Marrakech', 'tale'): -0.09933752,
#  ('Marrakech', 'span'): -0.11946924,
#  ('A', 'Tapestry'): 0.015716212,
#  ('A', 'Tradition'): -0.03192703,
#  ('A', 'Modernity'): -0.027740197,
#  ('A', 'Morocco'): 0.06316205,
#  ('A', 'locate'): 0.0030087437,
#  ('A', 'crossroad'): -0.15735684,
#  ('A', 'Europe'): 0.078128606,
#  ('A', 'Africa'): 0.06068073,
#  ('A', 'country'): 0.08539633,
#  ('A', 'drench'): 0.110322125,
#  ('A', 'history'): -0.101385206,
#  ('A', 'mystery'): 0.16687407,
#  ('A', 'cultural'): -0.06378201,
#  ('A', 'richness'): -0.029672135,
#  ('A', 'a'): 0.09801883,
#  ('A', 'testament'): 0.12852527,
#  ('A', 'ancient'): 0.030183434,
#  ('A', 'civilization'): -0.16223492,
#  ('A', 'flourish'): -0.07243859,
#  ('A', 'north'): 0.10257263,
#  ('A', 'african'): 0.1223839,
#  ('A', 'kingdom'): -0.0856738,
#  ('A', 'boast'): 0.061697878,
#  ('A', 'unique'): -0.0060527674,
#  ('A', 'blend'): 0.0025326235,
#  ('A', 'arab'): 0.040106744,
#  ('A', 'Berber'): 0.021305546,
#  ('A', 'european'): 0.1824963,
#  ('A', 'influence'): -0.0076826587,
#  ('A', 'at'): -0.0457963,
#  ('A', 'heart'): -0.05202231,
#  ('A', 'Moroccos'): -0.106437154,
#  ('A', 'rich'): 0.001690804,
#  ('A', 'tapestry'): -0.02206241,
#  ('A', 'lie'): -0.045140047,
#  ('A', 'Marrakech'): -0.06448211,
#  ('A', 'one'): -0.13524356,
#  ('A', 'four'): 0.04065627,
#  ('A', 'imperial'): 0.0002564604,
#  ('A', 'city'): 0.05879568,
#  ('A', 'vibrant'): -0.021267878,
#  ('A', 'epicenter'): 0.15339236,
#  ('A', 'tradition'): 0.08898377,
#  ('A', 'modernity'): -0.034474745,
#  ('A', 'geographical'): -0.071931735,
#  ('A', 'Significance'): 0.1837007,
#  ('A', 'border'): -0.12657247,
#  ('A', 'Atlantic'): -0.18626189,
#  ('A', 'Ocean'): -0.057319656,
#  ('A', 'west'): 0.04705065,
#  ('A', 'Mediterranean'): -0.102993794,
#  ('A', 'Sea'): 0.022693604,
#  ('A', 'Algeria'): -0.051657192,
#  ('A', 'east'): -0.020287106,
#  ('A', 'southeast'): -0.045407433,
#  ('A', 'vast'): -0.034161724,
#  ('A', 'Sahara'): 0.036612768,
#  ('A', 'desert'): 0.08422568,
#  ('A', 'south'): 0.0234968,
#  ('A', 'its'): 0.11706082,
#  ('A', 'strategic'): 0.15675028,
#  ('A', 'location'): 0.11097252,
#  ('A', 'historically'): -0.10062142,
#  ('A', 'make'): 0.055386998,
#  ('A', 'soughtafter'): -0.03613695,
#  ('A', 'territory'): -0.122139074,
#  ('A', 'melting'): -0.24596667,
#  ('A', 'pot'): 0.1067352,
#  ('A', 'culture'): 0.062603146,
#  ('A', 'religion'): -0.03981253,
#  ('A', 'trade'): 0.027259657,
#  ('A', 'route'): -0.12148593,
#  ('A', 'the'): -0.10747342,
#  ('A', 'Red'): 0.08787017,
#  ('A', 'City'): -0.062212165,
#  ('A', 'often'): 0.08881071,
#  ('A', 'refer'): 0.13192773,
#  ('A', 'due'): 0.024617085,
#  ('A', 'distinctive'): 0.06440987,
#  ('A', 'redhue'): -0.20616047,
#  ('A', 'building'): 0.09698587,
#  ('A', 'stand'): 0.007719815,
#  ('A', 'backdrop'): 0.04643692,
#  ('A', 'snowcappe'): 0.12486269,
#  ('A', 'Atlas'): -0.2502501,
#  ('A', 'Mountains'): 0.051471066,
#  ('A', 'establish'): 0.017296055,
#  ('A', '11th'): 0.045144547,
#  ('A', 'century'): -0.066778,
#  ('A', 'remain'): -0.046321917,
#  ('A', 'crucial'): 0.15155865,
#  ('A', 'political'): 0.12059894,
#  ('A', 'economic'): 0.051206823,
#  ('A', 'center'): -0.08078337,
#  ('A', 'Journey'): 0.040657543,
#  ('A', 'Medina'): -0.06607286,
#  ('A', 'Marrakechs'): 0.06077148,
#  ('A', 'old'): 0.053644177,
#  ('A', 'town'): 0.053434897,
#  ('A', 'UNESCO'): 0.031159177,
#  ('A', 'World'): -0.039183833,
#  ('A', 'Heritage'): 0.16788794,
#  ('A', 'site'): 0.05568643,
#  ('A', 'labyrinthine'): -0.13023019,
#  ('A', 'maze'): 0.014765167,
#  ('A', 'narrow'): -0.13713573,
#  ('A', 'alley'): -0.019565005,
#  ('A', 'bustle'): -0.117743865,
#  ('A', 'souks'): -0.04462473,
#  ('A', 'historical'): -0.027137011,
#  ('A', 'landmark'): -0.057581466,
#  ('A', 'Djemaa'): -0.07204698,
#  ('A', 'elfna'): -0.039314352,
#  ('A', 'Square'): -0.043211088,
#  ('A', 'come'): 0.029394642,
#  ('A', 'alive'): 0.07673644,
#  ('A', 'every'): 0.21587074,
#  ('A', 'evening'): 0.15354694,
#  ('A', 'storyteller'): -0.06027522,
#  ('A', 'musician'): 0.07168405,
#  ('A', 'snake'): 0.085051164,
#  ('A', 'charmer'): 0.06430502,
#  ('A', 'food'): -0.119174756,
#  ('A', 'stall'): 0.014528362,
#  ('A', 'offer'): -0.066099524,
#  ('A', 'tantalize'): -0.04972571,
#  ('A', 'Moroccan'): 0.073397614,
#  ('A', 'delicacy'): 0.16047803,
#  ('A', 'Palaces'): 0.007962197,
#  ('A', 'Gardens'): -0.08824895,
#  ('A', 'also'): 0.09518461,
#  ('A', 'home'): -0.06253721,
#  ('A', 'grand'): 0.06682193,
#  ('A', 'palace'): -0.09341711,
#  ('A', 'like'): -0.07963779,
#  ('A', 'Bahia'): -0.019005872,
#  ('A', 'Palace'): -0.07105565,
#  ('A', 'showcase'): -0.15595588,
#  ('A', 'intricate'): 0.09238615,
#  ('A', 'islamic'): -0.2059789,
#  ('A', 'architecture'): 0.10507545,
#  ('A', 'saadian'): 0.064541854,
#  ('A', 'Tombs'): 0.16373326,
#  ('A', 'remnant'): -0.11189421,
#  ('A', 'dynasty'): 0.036687024,
#  ('A', 'Majorelle'): -0.10156526,
#  ('A', 'Garden'): 0.13256055,
#  ('A', 'restore'): -0.06510585,
#  ('A', 'fashion'): -0.026157986,
#  ('A', 'designer'): 0.17216386,
#  ('A', 'Yves'): 0.049365193,
#  ('A', 'Saint'): 0.07686816,
#  ('A', 'Laurent'): 0.016954694,
#  ('A', 'tranquil'): -0.058171492,
#  ('A', 'oasis'): -0.019113064,
#  ('A', 'cacti'): 0.09379913,
#  ('A', 'palm'): -0.028672824,
#  ('A', 'tree'): -0.05466404,
#  ('A', 'cobalt'): 0.061257828,
#  ('A', 'blue'): 0.03979312,
#  ('A', 'accent'): -0.058763746,
#  ('A', 'Modern'): -0.04120116,
#  ('A', 'while'): 0.041617185,
#  ('A', 'permeate'): 0.017803352,
#  ('A', 'averse'): -0.117959425,
#  ('A', 'modern'): 0.039592624,
#  ('A', 'world'): -0.16142355,
#  ('A', 'Gueliz'): 0.08227717,
#  ('A', 'new'): -0.09198613,
#  ('A', 'brim'): 0.06691148,
#  ('A', 'contemporary'): -0.077019945,
#  ('A', 'art'): 0.057503045,
#  ('A', 'gallery'): 0.008054273,
#  ('A', 'stylish'): 0.070598245,
#  ('A', 'cafe'): 0.15910242,
#  ('A', 'chic'): -0.27257186,
#  ('A', 'boutique'): -0.09260103,
#  ('A', 'stark'): 0.13605724,
#  ('A', 'contrast'): -0.019711532,
#  ('A', 'Cuisine'): 0.28766853,
#  ('A', 'no'): -0.10924462,
#  ('A', 'journey'): -0.004107104,
#  ('A', 'would'): 0.10433593,
#  ('A', 'complete'): 0.23000021,
#  ('A', 'without'): 0.05877284,
#  ('A', 'indulge'): -0.0957954,
#  ('A', 'local'): -0.025706647,
#  ('A', 'cuisine'): -0.02513703,
#  ('A', 'tagine'): 0.055482548,
#  ('A', 'couscous'): -0.11887906,
#  ('A', 'pastilla'): 0.0067249746,
#  ('A', 'many'): -0.17386127,
#  ('A', 'dish'): -0.017363004,
#  ('A', 'combine'): -0.0125755,
#  ('A', 'plethora'): -0.0053765075,
#  ('A', 'flavors'): -0.0002523102,
#  ('A', 'spice'): -0.14754546,
#  ('A', 'saffron'): -0.1464731,
#  ('A', 'cumin'): 0.007897142,
#  ('A', 'mint'): 0.21460187,
#  ('A', 'pair'): 0.057128005,
#  ('A', 'moroccan'): 0.074076325,
#  ('A', 'tea'): 0.029185219,
#  ('A', 'culinary'): 0.017308824,
#  ('A', 'experience'): -0.0452407,
#  ('A', 'truly'): -0.1285377,
#  ('A', 'unparalleled'): -0.12083158,
#  ('A', 'in'): -0.11414665,
#  ('A', 'Conclusion'): -0.082907334,
#  ('A', 'traveler'): -0.07248879,
#  ('A', 'time'): -0.06011509,
#  ('A', 'convergence'): 0.07700756,
#  ('A', 'gastronomy'): 0.0028732184,
#  ('A', 'enthral'): 0.07549185,
#  ('A', 'destination'): -0.014726028,
#  ('A', 'seek'): -0.12545669,
#  ('A', 'adventure'): -0.048224628,
#  ('A', 'reflection'): 0.23339745,
#  ('A', 'as'): 0.0012713256,
#  ('A', 'proverb'): 0.014396222,
#  ('A', 'go'): 0.12459373,
#  ('A', 'he'): 0.051960263,
#  ('A', 'travel'): -0.036299404,
#  ('A', 'know'): 0.12750147,
#  ('A', 'value'): -0.07786904,
#  ('A', 'man'): 0.10113116,
#  ('A', 'case'): 0.0005126833,
#  ('A', 'tale'): 0.0406124,
#  ('A', 'span'): 0.04579216,
#  ('Tapestry', 'Tradition'): -0.07850612,
#  ('Tapestry', 'Modernity'): 0.016140968,
#  ('Tapestry', 'Morocco'): 0.039247967,
#  ('Tapestry', 'locate'): -0.011816156,
#  ('Tapestry', 'crossroad'): -0.07184854,
#  ('Tapestry', 'Europe'): -0.0539279,
#  ('Tapestry', 'Africa'): 0.023604132,
#  ('Tapestry', 'country'): -0.03473113,
#  ('Tapestry', 'drench'): 0.014348779,
#  ('Tapestry', 'history'): 0.06375961,
#  ('Tapestry', 'mystery'): -0.23115964,
#  ('Tapestry', 'cultural'): 0.011533407,
#  ('Tapestry', 'richness'): 0.08188831,
#  ('Tapestry', 'a'): 0.025506563,
#  ('Tapestry', 'testament'): 0.100799136,
#  ('Tapestry', 'ancient'): -0.08579683,
#  ('Tapestry', 'civilization'): -0.11000139,
#  ('Tapestry', 'flourish'): -0.16160156,
#  ('Tapestry', 'north'): -0.043550074,
#  ('Tapestry', 'african'): 0.01073397,
#  ('Tapestry', 'kingdom'): -0.03741745,
#  ('Tapestry', 'boast'): 0.07725076,
#  ('Tapestry', 'unique'): -0.13732122,
#  ('Tapestry', 'blend'): 0.09818992,
#  ('Tapestry', 'arab'): 0.096696824,
#  ('Tapestry', 'Berber'): 0.17558505,
#  ('Tapestry', 'european'): 0.14214227,
#  ('Tapestry', 'influence'): 0.051502347,
#  ('Tapestry', 'at'): 0.07259331,
#  ('Tapestry', 'heart'): -0.058770522,
#  ('Tapestry', 'Moroccos'): -0.05609957,
#  ('Tapestry', 'rich'): 0.1356448,
#  ('Tapestry', 'tapestry'): 0.076172404,
#  ('Tapestry', 'lie'): -0.057332776,
#  ('Tapestry', 'Marrakech'): 0.14008935,
#  ('Tapestry', 'one'): 0.08921664,
#  ('Tapestry', 'four'): 0.08879426,
#  ('Tapestry', 'imperial'): 0.23654039,
#  ('Tapestry', 'city'): -0.14502059,
#  ('Tapestry', 'vibrant'): -0.06421234,
#  ('Tapestry', 'epicenter'): 0.12871455,
#  ('Tapestry', 'tradition'): -0.018373674,
#  ('Tapestry', 'modernity'): -0.12668954,
#  ('Tapestry', 'geographical'): -0.07073027,
#  ('Tapestry', 'Significance'): 0.1480365,
#  ('Tapestry', 'border'): -0.1464226,
#  ('Tapestry', 'Atlantic'): 0.056368034,
#  ('Tapestry', 'Ocean'): 0.063041955,
#  ('Tapestry', 'west'): 0.117277175,
#  ('Tapestry', 'Mediterranean'): -0.042356055,
#  ('Tapestry', 'Sea'): 0.04872146,
#  ('Tapestry', 'Algeria'): 0.010439026,
#  ('Tapestry', 'east'): -0.08951901,
#  ('Tapestry', 'southeast'): -0.020045636,
#  ('Tapestry', 'vast'): -0.11301328,
#  ('Tapestry', 'Sahara'): -0.24016273,
#  ('Tapestry', 'desert'): -0.02534074,
#  ('Tapestry', 'south'): -0.012446527,
#  ('Tapestry', 'its'): 0.14874387,
#  ('Tapestry', 'strategic'): 0.15907829,
#  ('Tapestry', 'location'): -0.14064226,
#  ('Tapestry', 'historically'): 0.14013687,
#  ('Tapestry', 'make'): 0.07562058,
#  ('Tapestry', 'soughtafter'): -0.09602185,
#  ('Tapestry', 'territory'): 0.08553054,
#  ('Tapestry', 'melting'): -0.07727983,
#  ('Tapestry', 'pot'): -0.09567252,
#  ('Tapestry', 'culture'): -0.08680884,
#  ('Tapestry', 'religion'): -0.017657924,
#  ('Tapestry', 'trade'): 0.062149543,
#  ('Tapestry', 'route'): 0.13452145,
#  ('Tapestry', 'the'): -0.030925436,
#  ('Tapestry', 'Red'): 0.15759178,
#  ('Tapestry', 'City'): -0.16120602,
#  ('Tapestry', 'often'): 0.11833634,
#  ('Tapestry', 'refer'): -0.00969953,
#  ('Tapestry', 'due'): -0.1482472,
#  ('Tapestry', 'distinctive'): 0.029511422,
#  ('Tapestry', 'redhue'): 0.15375216,
#  ('Tapestry', 'building'): 0.05464534,
#  ('Tapestry', 'stand'): 0.2288565,
#  ('Tapestry', 'backdrop'): -0.029048473,
#  ('Tapestry', 'snowcappe'): 0.02510342,
#  ('Tapestry', 'Atlas'): -0.091461994,
#  ('Tapestry', 'Mountains'): -0.03465303,
#  ('Tapestry', 'establish'): -0.097165614,
#  ('Tapestry', '11th'): -0.13247263,
#  ('Tapestry', 'century'): -0.049578752,
#  ('Tapestry', 'remain'): -0.04507808,
#  ('Tapestry', 'crucial'): -0.21585147,
#  ('Tapestry', 'political'): 0.12803315,
#  ('Tapestry', 'economic'): -0.001377962,
#  ('Tapestry', 'center'): -0.01068482,
#  ('Tapestry', 'Journey'): 0.05340545,
#  ('Tapestry', 'Medina'): 0.009033981,
#  ('Tapestry', 'Marrakechs'): 0.118645,
#  ('Tapestry', 'old'): 0.09251799,
#  ('Tapestry', 'town'): 0.030012654,
#  ('Tapestry', 'UNESCO'): 0.2602011,
#  ('Tapestry', 'World'): -0.22501062,
#  ('Tapestry', 'Heritage'): 0.07248197,
#  ('Tapestry', 'site'): -0.15000588,
#  ('Tapestry', 'labyrinthine'): -0.054861948,
#  ('Tapestry', 'maze'): -0.061589085,
#  ('Tapestry', 'narrow'): 0.07009934,
#  ('Tapestry', 'alley'): 0.048663627,
#  ('Tapestry', 'bustle'): 0.006376706,
#  ('Tapestry', 'souks'): -0.018124644,
#  ('Tapestry', 'historical'): 0.037377317,
#  ('Tapestry', 'landmark'): 0.121841274,
#  ('Tapestry', 'Djemaa'): 0.05368608,
#  ('Tapestry', 'elfna'): -0.16002923,
#  ('Tapestry', 'Square'): 0.003478629,
#  ('Tapestry', 'come'): 0.022993099,
#  ('Tapestry', 'alive'): 0.02688086,
#  ('Tapestry', 'every'): 0.03201101,
#  ('Tapestry', 'evening'): -0.25181973,
#  ('Tapestry', 'storyteller'): -0.1308004,
#  ('Tapestry', 'musician'): 0.15011914,
#  ('Tapestry', 'snake'): -0.15111643,
#  ('Tapestry', 'charmer'): 0.12833402,
#  ('Tapestry', 'food'): -0.027265025,
#  ('Tapestry', 'stall'): 0.025132664,
#  ('Tapestry', 'offer'): 0.15423955,
#  ('Tapestry', 'tantalize'): -0.072937384,
#  ('Tapestry', 'Moroccan'): 0.02025483,
#  ('Tapestry', 'delicacy'): 0.12221849,
#  ('Tapestry', 'Palaces'): 0.029748999,
#  ('Tapestry', 'Gardens'): 0.007271961,
#  ('Tapestry', 'also'): -0.13817273,
#  ('Tapestry', 'home'): 0.08839431,
#  ('Tapestry', 'grand'): -0.00281972,
#  ('Tapestry', 'palace'): -0.02849559,
#  ('Tapestry', 'like'): -0.09500693,
#  ('Tapestry', 'Bahia'): 0.030175585,
#  ('Tapestry', 'Palace'): -0.20516631,
#  ('Tapestry', 'showcase'): -0.061405282,
#  ('Tapestry', 'intricate'): 0.15694457,
#  ('Tapestry', 'islamic'): 0.13552709,
#  ('Tapestry', 'architecture'): 0.07113271,
#  ('Tapestry', 'saadian'): -0.00014169235,
#  ('Tapestry', 'Tombs'): -0.010599395,
#  ('Tapestry', 'remnant'): 0.233402,
#  ('Tapestry', 'dynasty'): -0.029118812,
#  ('Tapestry', 'Majorelle'): 0.07530081,
#  ('Tapestry', 'Garden'): 0.107681125,
#  ('Tapestry', 'restore'): -0.051641166,
#  ('Tapestry', 'fashion'): 0.03821296,
#  ('Tapestry', 'designer'): 0.087228246,
#  ('Tapestry', 'Yves'): 0.016772272,
#  ('Tapestry', 'Saint'): 0.031308156,
#  ('Tapestry', 'Laurent'): -0.080498874,
#  ('Tapestry', 'tranquil'): -0.10467343,
#  ('Tapestry', 'oasis'): 0.043972682,
#  ('Tapestry', 'cacti'): -0.07477797,
#  ('Tapestry', 'palm'): 0.03415553,
#  ('Tapestry', 'tree'): -0.11911928,
#  ('Tapestry', 'cobalt'): 0.04628799,
#  ('Tapestry', 'blue'): 0.083874695,
#  ('Tapestry', 'accent'): 0.17971462,
#  ('Tapestry', 'Modern'): 0.17283171,
#  ('Tapestry', 'while'): 0.052780762,
#  ('Tapestry', 'permeate'): -0.045093324,
#  ('Tapestry', 'averse'): 0.032997042,
#  ('Tapestry', 'modern'): 0.18723994,
#  ('Tapestry', 'world'): 0.08675761,
#  ('Tapestry', 'Gueliz'): -0.16429703,
#  ('Tapestry', 'new'): -0.0535068,
#  ('Tapestry', 'brim'): -0.130746,
#  ('Tapestry', 'contemporary'): -0.07944571,
#  ('Tapestry', 'art'): 0.15451173,
#  ('Tapestry', 'gallery'): -0.0634205,
#  ('Tapestry', 'stylish'): -0.13147438,
#  ('Tapestry', 'cafe'): -0.067962214,
#  ('Tapestry', 'chic'): -0.07589889,
#  ('Tapestry', 'boutique'): -0.059147887,
#  ('Tapestry', 'stark'): 0.054669525,
#  ('Tapestry', 'contrast'): 0.15455401,
#  ('Tapestry', 'Cuisine'): -0.04644288,
#  ('Tapestry', 'no'): 0.053161908,
#  ('Tapestry', 'journey'): 0.07639412,
#  ('Tapestry', 'would'): 0.12448495,
#  ('Tapestry', 'complete'): 0.041085366,
#  ('Tapestry', 'without'): 0.24296857,
#  ('Tapestry', 'indulge'): 0.06737626,
#  ('Tapestry', 'local'): 0.23046422,
#  ('Tapestry', 'cuisine'): -0.007225616,
#  ('Tapestry', 'tagine'): -0.121750765,
#  ('Tapestry', 'couscous'): -0.022165563,
#  ('Tapestry', 'pastilla'): -0.035552345,
#  ('Tapestry', 'many'): -0.13978718,
#  ('Tapestry', 'dish'): -0.08756887,
#  ('Tapestry', 'combine'): 0.066560924,
#  ('Tapestry', 'plethora'): -0.06601307,
#  ('Tapestry', 'flavors'): 0.05190474,
#  ('Tapestry', 'spice'): 0.0918428,
#  ('Tapestry', 'saffron'): 0.014272086,
#  ('Tapestry', 'cumin'): -0.07964107,
#  ('Tapestry', 'mint'): 0.021612221,
#  ('Tapestry', 'pair'): -0.012095208,
#  ('Tapestry', 'moroccan'): 0.0198747,
#  ('Tapestry', 'tea'): 0.006614352,
#  ('Tapestry', 'culinary'): -0.13201326,
#  ('Tapestry', 'experience'): -0.06951971,
#  ('Tapestry', 'truly'): 0.0016060378,
#  ('Tapestry', 'unparalleled'): 0.012734255,
#  ('Tapestry', 'in'): 0.03119033,
#  ('Tapestry', 'Conclusion'): 0.019924905,
#  ('Tapestry', 'traveler'): -0.025817081,
#  ('Tapestry', 'time'): -0.05781137,
#  ('Tapestry', 'convergence'): -0.08039428,
#  ('Tapestry', 'gastronomy'): -0.09624667,
#  ('Tapestry', 'enthral'): 0.14001934,
#  ('Tapestry', 'destination'): -0.09257459,
#  ('Tapestry', 'seek'): -0.0035195597,
#  ('Tapestry', 'adventure'): 0.10216818,
#  ('Tapestry', 'reflection'): -0.092095934,
#  ('Tapestry', 'as'): 0.11460384,
#  ('Tapestry', 'proverb'): -0.2063942,
#  ('Tapestry', 'go'): -0.006131665,
#  ('Tapestry', 'he'): -0.02427862,
#  ('Tapestry', 'travel'): -0.1178086,
#  ('Tapestry', 'know'): -0.07815264,
#  ('Tapestry', 'value'): 0.1301322,
#  ('Tapestry', 'man'): -0.08948527,
#  ('Tapestry', 'case'): -0.052458104,
#  ('Tapestry', 'tale'): -0.10950513,
#  ('Tapestry', 'span'): -0.15150169,
#  ('Tradition', 'Modernity'): 0.10769953,
#  ('Tradition', 'Morocco'): -0.07628815,
#  ('Tradition', 'locate'): 0.028558208,
#  ('Tradition', 'crossroad'): -0.08650633,
#  ('Tradition', 'Europe'): -0.011320213,
#  ('Tradition', 'Africa'): -0.018770413,
#  ('Tradition', 'country'): 0.13019568,
#  ('Tradition', 'drench'): 0.17920774,
#  ('Tradition', 'history'): -0.122883715,
#  ('Tradition', 'mystery'): 0.110299736,
#  ('Tradition', 'cultural'): -0.099625714,
#  ('Tradition', 'richness'): -0.028913816,
#  ('Tradition', 'a'): -0.12764156,
#  ('Tradition', 'testament'): 0.0205802,
#  ('Tradition', 'ancient'): -0.16705593,
#  ('Tradition', 'civilization'): 0.11553756,
#  ('Tradition', 'flourish'): 0.06387323,
#  ('Tradition', 'north'): -0.18871263,
#  ('Tradition', 'african'): 0.05172802,
#  ('Tradition', 'kingdom'): -0.028832441,
#  ('Tradition', 'boast'): 0.04169612,
#  ('Tradition', 'unique'): 0.10298383,
#  ('Tradition', 'blend'): 0.10960285,
#  ('Tradition', 'arab'): 0.036236275,
#  ('Tradition', 'Berber'): -0.032801364,
#  ('Tradition', 'european'): 0.1089537,
#  ('Tradition', 'influence'): 0.024191624,
#  ('Tradition', 'at'): 0.19604981,
#  ('Tradition', 'heart'): 0.0088589825,
#  ('Tradition', 'Moroccos'): -0.085325874,
#  ('Tradition', 'rich'): -0.19592965,
#  ('Tradition', 'tapestry'): -0.07773729,
#  ('Tradition', 'lie'): 0.035017397,
#  ('Tradition', 'Marrakech'): -0.026529504,
#  ('Tradition', 'one'): -0.15464306,
#  ('Tradition', 'four'): -0.046990454,
#  ('Tradition', 'imperial'): -0.17842695,
#  ('Tradition', 'city'): 0.1246804,
#  ('Tradition', 'vibrant'): 0.052283302,
#  ('Tradition', 'epicenter'): 0.07314118,
#  ('Tradition', 'tradition'): 0.11416328,
#  ('Tradition', 'modernity'): 0.14041321,
#  ('Tradition', 'geographical'): 0.073201455,
#  ('Tradition', 'Significance'): -0.08709498,
#  ('Tradition', 'border'): -0.11133271,
#  ('Tradition', 'Atlantic'): -0.16811748,
#  ('Tradition', 'Ocean'): 0.042026285,
#  ('Tradition', 'west'): 0.054140147,
#  ('Tradition', 'Mediterranean'): -0.052259304,
#  ('Tradition', 'Sea'): 0.009614632,
#  ('Tradition', 'Algeria'): 0.15073077,
#  ('Tradition', 'east'): -0.15229772,
#  ('Tradition', 'southeast'): 0.12387989,
#  ('Tradition', 'vast'): 0.11969755,
#  ('Tradition', 'Sahara'): -0.057607446,
#  ('Tradition', 'desert'): 0.03985334,
#  ('Tradition', 'south'): 0.08586083,
#  ('Tradition', 'its'): -0.080809355,
#  ('Tradition', 'strategic'): 0.035365395,
#  ('Tradition', 'location'): -0.08814632,
#  ('Tradition', 'historically'): 0.0068343827,
#  ('Tradition', 'make'): -0.07005246,
#  ('Tradition', 'soughtafter'): -0.013616469,
#  ('Tradition', 'territory'): 0.07989786,
#  ('Tradition', 'melting'): 0.038291976,
#  ('Tradition', 'pot'): 0.10180617,
#  ('Tradition', 'culture'): -0.20314947,
#  ('Tradition', 'religion'): -0.12892272,
#  ('Tradition', 'trade'): 0.16595615,
#  ('Tradition', 'route'): 0.27100372,
#  ('Tradition', 'the'): 0.048162494,
#  ('Tradition', 'Red'): 0.04172292,
#  ('Tradition', 'City'): -0.2534909,
#  ('Tradition', 'often'): 0.036015995,
#  ('Tradition', 'refer'): -0.090700224,
#  ('Tradition', 'due'): -0.063675195,
#  ('Tradition', 'distinctive'): 0.12334607,
#  ('Tradition', 'redhue'): -0.1276128,
#  ('Tradition', 'building'): 0.062308937,
#  ('Tradition', 'stand'): -0.050492954,
#  ('Tradition', 'backdrop'): -0.057189584,
#  ('Tradition', 'snowcappe'): 0.038385596,
#  ('Tradition', 'Atlas'): -0.010176799,
#  ...}

# %% [markdown]
# # **Contextual words**

# %%
window_size = 2
contextual_words = {}
for i, word in enumerate(tokenized_corpus[0]):
    left_context = tokenized_corpus[0][max(0, i - window_size):i]
    right_context = tokenized_corpus[0][i + 1:i + 1 + window_size]
    contextual_words[word] = left_context + right_context

# %%
contextual_words
# Out:
# {'Morocco': ['in', 'case', 'Marrakech', 'value'],
#  'Marrakech': ['case', 'Morocco', 'value', 'man'],
#  'A': ['Morocco', 'Marrakech', 'Tapestry', 'Tradition'],
#  'Tapestry': ['Marrakech', 'A', 'Tradition', 'Modernity'],
#  'Tradition': ['A', 'Tapestry', 'Modernity', 'Morocco'],
#  'Modernity': ['Tapestry', 'Tradition', 'Morocco', 'locate'],
#  'locate': ['Modernity', 'Morocco', 'crossroad', 'Europe'],
#  'crossroad': ['Morocco', 'locate', 'Europe', 'Africa'],
#  'Europe': ['locate', 'crossroad', 'Africa', 'country'],
#  'Africa': ['crossroad', 'Europe', 'country', 'drench'],
#  'country': ['Europe', 'Africa', 'drench', 'history'],
#  'drench': ['Africa', 'country', 'history', 'mystery'],
#  'history': ['the', 'convergence', 'culture', 'architecture'],
#  'mystery': ['drench', 'history', 'cultural', 'richness'],
#  'cultural': ['political', 'economic', 'center', 'Morocco'],
#  'richness': ['mystery', 'cultural', 'a', 'testament'],
#  'a': ['cultural', 'richness', 'testament', 'ancient'],
#  'testament': ['richness', 'a', 'ancient', 'civilization'],
#  'ancient': ['stark', 'contrast', 'Medina', 'Moroccan'],
#  'civilization': ['testament', 'ancient', 'flourish', 'north'],
#  'flourish': ['ancient', 'civilization', 'north', 'african'],
#  'north': ['Mediterranean', 'Sea', 'Algeria', 'east'],
#  'african': ['flourish', 'north', 'kingdom', 'boast'],
#  'kingdom': ['north', 'african', 'boast', 'unique'],
#  'boast': ['african', 'kingdom', 'unique', 'blend'],
#  'unique': ['kingdom', 'boast', 'blend', 'arab'],
#  'blend': ['boast', 'unique', 'arab', 'Berber'],
#  'arab': ['unique', 'blend', 'Berber', 'european'],
#  'Berber': ['blend', 'arab', 'european', 'influence'],
#  'european': ['arab', 'Berber', 'influence', 'at'],
#  'influence': ['Berber', 'european', 'at', 'heart'],
#  'at': ['european', 'influence', 'heart', 'Moroccos'],
#  'heart': ['Morocco', 'Marrakech', 'offer', 'traveler'],
#  'Moroccos': ['at', 'heart', 'rich', 'tapestry'],
#  'rich': ['heart', 'Moroccos', 'tapestry', 'lie'],
#  'tapestry': ['Moroccos', 'rich', 'lie', 'Marrakech'],
#  'lie': ['elfna', 'Square', 'heart', 'Medina'],
#  'one': ['lie', 'Marrakech', 'four', 'imperial'],
#  'four': ['Marrakech', 'one', 'imperial', 'city'],
#  'imperial': ['one', 'four', 'city', 'vibrant'],
#  'city': ['permeate', 'Marrakech', 'averse', 'modern'],
#  'vibrant': ['imperial', 'city', 'epicenter', 'tradition'],
#  'epicenter': ['city', 'vibrant', 'tradition', 'modernity'],
#  'tradition': ['value', 'time', 'tale', 'span'],
#  'modernity': ['epicenter', 'tradition', 'geographical', 'Significance'],
#  'geographical': ['tradition', 'modernity', 'Significance', 'Morocco'],
#  'Significance': ['modernity', 'geographical', 'Morocco', 'border'],
#  'border': ['Significance', 'Morocco', 'Atlantic', 'Ocean'],
#  'Atlantic': ['Morocco', 'border', 'Ocean', 'west'],
#  'Ocean': ['border', 'Atlantic', 'west', 'Mediterranean'],
#  'west': ['Atlantic', 'Ocean', 'Mediterranean', 'Sea'],
#  'Mediterranean': ['Ocean', 'west', 'Sea', 'north'],
#  'Sea': ['west', 'Mediterranean', 'north', 'Algeria'],
#  'Algeria': ['Sea', 'north', 'east', 'southeast'],
#  'east': ['north', 'Algeria', 'southeast', 'vast'],
#  'southeast': ['Algeria', 'east', 'vast', 'Sahara'],
#  'vast': ['east', 'southeast', 'Sahara', 'desert'],
#  'Sahara': ['southeast', 'vast', 'desert', 'south'],
#  'desert': ['vast', 'Sahara', 'south', 'its'],
#  'south': ['Sahara', 'desert', 'its', 'strategic'],
#  'its': ['desert', 'south', 'strategic', 'location'],
#  'strategic': ['south', 'its', 'location', 'historically'],
#  'location': ['its', 'strategic', 'historically', 'make'],
#  'historically': ['strategic', 'location', 'make', 'soughtafter'],
#  'make': ['architecture', 'gastronomy', 'enthral', 'destination'],
#  'soughtafter': ['historically', 'make', 'territory', 'melting'],
#  'territory': ['make', 'soughtafter', 'melting', 'pot'],
#  'melting': ['soughtafter', 'territory', 'pot', 'culture'],
#  'pot': ['territory', 'melting', 'culture', 'religion'],
#  'culture': ['convergence', 'history', 'architecture', 'gastronomy'],
#  'religion': ['pot', 'culture', 'trade', 'route'],
#  'trade': ['culture', 'religion', 'route', 'Marrakech'],
#  'route': ['religion', 'trade', 'Marrakech', 'the'],
#  'the': ['journey', 'time', 'convergence', 'history'],
#  'Red': ['refer', 'the', 'City', 'due'],
#  'City': ['the', 'Red', 'due', 'distinctive'],
#  'often': ['City', 'Marrakech', 'refer', 'the'],
#  'refer': ['Marrakech', 'often', 'the', 'Red'],
#  'due': ['Red', 'City', 'distinctive', 'redhue'],
#  'distinctive': ['City', 'due', 'redhue', 'building'],
#  'redhue': ['due', 'distinctive', 'building', 'stand'],
#  'building': ['distinctive', 'redhue', 'stand', 'backdrop'],
#  'stand': ['redhue', 'building', 'backdrop', 'snowcappe'],
#  'backdrop': ['building', 'stand', 'snowcappe', 'Atlas'],
#  'snowcappe': ['stand', 'backdrop', 'Atlas', 'Mountains'],
#  'Atlas': ['backdrop', 'snowcappe', 'Mountains', 'establish'],
#  'Mountains': ['snowcappe', 'Atlas', 'establish', '11th'],
#  'establish': ['Atlas', 'Mountains', '11th', 'century'],
#  '11th': ['Mountains', 'establish', 'century', 'remain'],
#  'century': ['tale', 'span'],
#  'remain': ['11th', 'century', 'crucial', 'political'],
#  'crucial': ['century', 'remain', 'political', 'economic'],
#  'political': ['remain', 'crucial', 'economic', 'cultural'],
#  'economic': ['crucial', 'political', 'cultural', 'center'],
#  'center': ['economic', 'cultural', 'Morocco', 'Journey'],
#  'Journey': ['center', 'Morocco', 'Medina', 'Marrakechs'],
#  'Medina': ['contrast', 'ancient', 'Moroccan', 'Cuisine'],
#  'Marrakechs': ['Journey', 'Medina', 'old', 'town'],
#  'old': ['Medina', 'Marrakechs', 'town', 'Medina'],
#  'town': ['Gueliz', 'new', 'brim', 'contemporary'],
#  'UNESCO': ['town', 'Medina', 'World', 'Heritage'],
#  'World': ['Medina', 'UNESCO', 'Heritage', 'site'],
#  'Heritage': ['UNESCO', 'World', 'site', 'labyrinthine'],
#  'site': ['World', 'Heritage', 'labyrinthine', 'maze'],
#  'labyrinthine': ['Heritage', 'site', 'maze', 'narrow'],
#  'maze': ['site', 'labyrinthine', 'narrow', 'alley'],
#  'narrow': ['labyrinthine', 'maze', 'alley', 'bustle'],
#  'alley': ['maze', 'narrow', 'bustle', 'souks'],
#  'bustle': ['narrow', 'alley', 'souks', 'historical'],
#  'souks': ['alley', 'bustle', 'historical', 'landmark'],
#  'historical': ['bustle', 'souks', 'landmark', 'the'],
#  'landmark': ['souks', 'historical', 'the', 'Djemaa'],
#  'Djemaa': ['landmark', 'the', 'elfna', 'Square'],
#  'elfna': ['the', 'Djemaa', 'Square', 'lie'],
#  'Square': ['Djemaa', 'elfna', 'lie', 'heart'],
#  'come': ['heart', 'Medina', 'alive', 'every'],
#  'alive': ['Medina', 'come', 'every', 'evening'],
#  'every': ['come', 'alive', 'evening', 'storyteller'],
#  'evening': ['alive', 'every', 'storyteller', 'musician'],
#  'storyteller': ['every', 'evening', 'musician', 'snake'],
#  'musician': ['evening', 'storyteller', 'snake', 'charmer'],
#  'snake': ['storyteller', 'musician', 'charmer', 'food'],
#  'charmer': ['musician', 'snake', 'food', 'stall'],
#  'food': ['snake', 'charmer', 'stall', 'offer'],
#  'stall': ['charmer', 'food', 'offer', 'tantalize'],
#  'offer': ['Marrakech', 'heart', 'traveler', 'unparalleled'],
#  'tantalize': ['stall', 'offer', 'Moroccan', 'delicacy'],
#  'Moroccan': ['ancient', 'Medina', 'Cuisine', 'no'],
#  'delicacy': ['tantalize', 'Moroccan', 'Palaces', 'Gardens'],
#  'Palaces': ['Moroccan', 'delicacy', 'Gardens', 'the'],
#  'Gardens': ['delicacy', 'Palaces', 'the', 'city'],
#  'also': ['value', 'man', 'value', 'time'],
#  'home': ['city', 'also', 'grand', 'palace'],
#  'grand': ['also', 'home', 'palace', 'like'],
#  'palace': ['home', 'grand', 'like', 'Bahia'],
#  'like': ['flavors', 'spice', 'saffron', 'cumin'],
#  'Bahia': ['palace', 'like', 'Palace', 'showcase'],
#  'Palace': ['like', 'Bahia', 'showcase', 'intricate'],
#  'showcase': ['Bahia', 'Palace', 'intricate', 'islamic'],
#  'intricate': ['Palace', 'showcase', 'islamic', 'architecture'],
#  'islamic': ['showcase', 'intricate', 'architecture', 'saadian'],
#  'architecture': ['history', 'culture', 'gastronomy', 'make'],
#  'saadian': ['Tombs', 'remnant', 'dynasty', 'the'],
#  'Tombs': ['architecture', 'saadian', 'remnant', 'saadian'],
#  'remnant': ['saadian', 'Tombs', 'saadian', 'dynasty'],
#  'dynasty': ['remnant', 'saadian', 'the', 'Majorelle'],
#  'Majorelle': ['dynasty', 'the', 'Garden', 'restore'],
#  'Garden': ['the', 'Majorelle', 'restore', 'fashion'],
#  'restore': ['Majorelle', 'Garden', 'fashion', 'designer'],
#  'fashion': ['Garden', 'restore', 'designer', 'Yves'],
#  'designer': ['restore', 'fashion', 'Yves', 'Saint'],
#  'Yves': ['fashion', 'designer', 'Saint', 'Laurent'],
#  'Saint': ['designer', 'Yves', 'Laurent', 'tranquil'],
#  'Laurent': ['Yves', 'Saint', 'tranquil', 'oasis'],
#  'tranquil': ['Saint', 'Laurent', 'oasis', 'cacti'],
#  'oasis': ['Laurent', 'tranquil', 'cacti', 'palm'],
#  'cacti': ['tranquil', 'oasis', 'palm', 'tree'],
#  'palm': ['oasis', 'cacti', 'tree', 'cobalt'],
#  'tree': ['cacti', 'palm', 'cobalt', 'blue'],
#  'cobalt': ['palm', 'tree', 'blue', 'accent'],
#  'blue': ['tree', 'cobalt', 'accent', 'Modern'],
#  'accent': ['cobalt', 'blue', 'Modern', 'Marrakech'],
#  'Modern': ['blue', 'accent', 'Marrakech', 'while'],
#  'while': ['Modern', 'Marrakech', 'tradition', 'history'],
#  'permeate': ['tradition', 'history', 'Marrakech', 'city'],
#  'averse': ['Marrakech', 'city', 'modern', 'world'],
#  'modern': ['city', 'averse', 'world', 'Gueliz'],
#  'world': ['averse', 'modern', 'Gueliz', 'new'],
#  'Gueliz': ['modern', 'world', 'new', 'town'],
#  'new': ['world', 'Gueliz', 'town', 'brim'],
#  'brim': ['new', 'town', 'contemporary', 'art'],
#  'contemporary': ['town', 'brim', 'art', 'gallery'],
#  'art': ['brim', 'contemporary', 'gallery', 'stylish'],
#  'gallery': ['contemporary', 'art', 'stylish', 'cafe'],
#  'stylish': ['art', 'gallery', 'cafe', 'chic'],
#  'cafe': ['gallery', 'stylish', 'chic', 'boutique'],
#  'chic': ['stylish', 'cafe', 'boutique', 'offer'],
#  'boutique': ['cafe', 'chic', 'offer', 'stark'],
#  'stark': ['boutique', 'offer', 'contrast', 'ancient'],
#  'contrast': ['offer', 'stark', 'ancient', 'Medina'],
#  'Cuisine': ['Medina', 'Moroccan', 'no', 'journey'],
#  'no': ['Moroccan', 'Cuisine', 'journey', 'Morocco'],
#  'journey': ['traveler', 'unparalleled', 'time', 'the'],
#  'would': ['Morocco', 'Marrakech', 'complete', 'without'],
#  'complete': ['Marrakech', 'would', 'without', 'indulge'],
#  'without': ['would', 'complete', 'indulge', 'local'],
#  'indulge': ['complete', 'without', 'local', 'cuisine'],
#  'local': ['without', 'indulge', 'cuisine', 'tagine'],
#  'cuisine': ['indulge', 'local', 'tagine', 'couscous'],
#  'tagine': ['local', 'cuisine', 'couscous', 'pastilla'],
#  'couscous': ['cuisine', 'tagine', 'pastilla', 'many'],
#  'pastilla': ['tagine', 'couscous', 'many', 'dish'],
#  'many': ['couscous', 'pastilla', 'dish', 'combine'],
#  'dish': ['pastilla', 'many', 'combine', 'plethora'],
#  'combine': ['many', 'dish', 'plethora', 'flavors'],
#  'plethora': ['dish', 'combine', 'flavors', 'spice'],
#  'flavors': ['combine', 'plethora', 'spice', 'like'],
#  'spice': ['plethora', 'flavors', 'like', 'saffron'],
#  'saffron': ['spice', 'like', 'cumin', 'mint'],
#  'cumin': ['like', 'saffron', 'mint', 'pair'],
#  'mint': ['pair', 'moroccan', 'tea', 'culinary'],
#  'pair': ['cumin', 'mint', 'moroccan', 'mint'],
#  'moroccan': ['reflection', 'as', 'proverb', 'go'],
#  'tea': ['moroccan', 'mint', 'culinary', 'experience'],
#  'culinary': ['mint', 'tea', 'experience', 'truly'],
#  'experience': ['tea', 'culinary', 'truly', 'unparalleled'],
#  'truly': ['culinary', 'experience', 'unparalleled', 'in'],
#  'unparalleled': ['offer', 'traveler', 'journey', 'time'],
#  'in': ['value', 'man', 'case', 'Morocco'],
#  'Conclusion': ['unparalleled', 'in', 'Morocco', 'Marrakech'],
#  'traveler': ['heart', 'offer', 'unparalleled', 'journey'],
#  'time': ['also', 'value', 'tradition', 'tale'],
#  'convergence': ['time', 'the', 'history', 'culture'],
#  'gastronomy': ['culture', 'architecture', 'make', 'enthral'],
#  'enthral': ['gastronomy', 'make', 'destination', 'seek'],
#  'destination': ['make', 'enthral', 'seek', 'adventure'],
#  'seek': ['enthral', 'destination', 'adventure', 'reflection'],
#  'adventure': ['destination', 'seek', 'reflection', 'as'],
#  'reflection': ['seek', 'adventure', 'as', 'moroccan'],
#  'as': ['adventure', 'reflection', 'moroccan', 'proverb'],
#  'proverb': ['as', 'moroccan', 'go', 'he'],
#  'go': ['moroccan', 'proverb', 'he', 'travel'],
#  'he': ['proverb', 'go', 'travel', 'know'],
#  'travel': ['go', 'he', 'know', 'value'],
#  'know': ['he', 'travel', 'value', 'man'],
#  'value': ['man', 'also', 'time', 'tradition'],
#  'man': ['Marrakech', 'value', 'also', 'value'],
#  'case': ['man', 'in', 'Morocco', 'Marrakech'],
#  'tale': ['time', 'tradition', 'span', 'century'],
#  'span': ['tradition', 'tale', 'century']}
